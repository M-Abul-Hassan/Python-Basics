# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Abul-Hassan/Python-Basics/blob/main/DL_Neural_Network_Tensorflow_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Neural Network

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.13.0

# %%
# Simplest Sequential layer neural network

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd' , loss = 'mean_squared_error')

# %%
# Make numpy arrays for data

xs =  np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0 ], dtype = float )
ys =  np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0 ], dtype = float )

# %%
# Training of Neural Netwok
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 18ms/step - loss: 6.5022e-05
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 6.3688e-05
# Epoch 3/500
# 1/1 [==============================] - 0s 17ms/step - loss: 6.2379e-05
# Epoch 4/500
# 1/1 [==============================] - 0s 15ms/step - loss: 6.1098e-05
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.9844e-05
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8614e-05
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.7410e-05
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6231e-05
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.5077e-05
# Epoch 10/500
# 1/1 [==============================] - 0s 15ms/step - loss: 5.3945e-05
# Epoch 11/500
# 1/1 [==============================] - 0s 13ms/step - loss: 5.2837e-05
# Epoch 12/500
# ...

# %%
print(model.predict([20]))
# Out:
# 1/1 [==============================] - 0s 66ms/step
# [[38.999676]]

# %%
print(model.predict([10]))
# Out:
# 1/1 [==============================] - 0s 44ms/step
# [[18.999866]]

# %% [markdown]
# **We can predict the model by using the Neural Network**
#
# **Y=2X-1**
#
# We can find the value of **'Y'**
#
#
# If I want to find the value of Y and want to predict the value....we add the value of X in the equation it will gives the value if Y

# %%
print(model.predict([11]))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[20.999847]]
